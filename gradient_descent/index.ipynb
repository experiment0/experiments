# %%
import numpy as np
from sympy import *
# %matplotlib inline

from classes.GradientDescent import GradientDescent

# %% [markdown]
# Зададим начальные условия.

# %%
# Переменные функции
x, y = symbols('x y', real=True)

# Функция Розенброка
function = (1 - x)**2 + 100*(y - x**2)**2

# Запускаем работу градиентного спуска
gradient_descent = GradientDescent(
    function, 
    x, 
    y,
    point_start = np.array([-2, -2]),
)
gradient_descent.run()
# Out:
# ---------------------------------
# Данные последней найденной точки:
# Номер шага: 21960
# Координаты точки: x=0.9988, y=0.9975
# Значение функции в точке: 0.0000
# Вектор градиента в точке: (-0.0005, -0.0010)
